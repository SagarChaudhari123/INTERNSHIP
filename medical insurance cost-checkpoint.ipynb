# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
data=pd.read_csv("medical_cost_insurance.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# #from above information
# standard deviation is very high in age,charges that means data is too spread
# there is a difference between bmi ,charges in 75% and maximum that means outliers are present in that coumns.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.charges
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.sample(5)
# Out:
#       age     sex    bmi  children smoker     region      charges
# 132    53  female  35.90         2     no  southwest  11163.56800
# 12     23    male  34.40         0     no  southwest   1826.84300
# 205    28  female  28.88         1     no  northeast   4337.73520
# 526    19  female  30.59         2     no  northwest  24059.68019
# 1234   45  female  27.83         2     no  southeast   8515.75870

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
clean_data = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
data_copy = data.copy()
data_copy.replace(clean_data, inplace=True)

# %%
data_copy.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.514948  13270.422265
# std       1.105572  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
data_copy['age'].plot.box()
# Out:
# <Axes: >

# %%
sns.pairplot(data_copy)

# %%
data_copy['bmi'].plot.box()
# Out:
# <Axes: >

# %%
data_copy['charges'].plot.box()
# Out:
# <Axes: >

# %%
data_copy['children'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # Now remove outliers from bmi cloumns

# %%
from scipy.stats import zscore
import numpy as np

# %%
data_copy.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.037853
# charges     1.515880
# dtype: float64

# %%
data_copy['charges'].plot.box()
# Out:
# <Axes: >

# %%
data_copy['charges'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_copy['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_copy['bmi'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_copy['children'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_copy.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.heatmap(data_copy.corr())
# Out:
# <Axes: >

# %% [markdown]
# # bmi and age are the most important to determine charges

# %%
print(data['sex'].value_counts().sort_values()) 
print(data['smoker'].value_counts().sort_values())
print(data['region'].value_counts().sort_values())
# Out:
# female    662
# male      676
# Name: sex, dtype: int64
# yes     274
# no     1064
# Name: smoker, dtype: int64
# northeast    324
# southwest    325
# northwest    325
# southeast    364
# Name: region, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='bmi',y='charges',hue='sex',data=data_copy,palette='Reds')
plt.title('BMI VS Charge')
# Out:
# Text(0.5, 1.0, 'BMI VS Charge')

# %%
clean_data = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
data_copy = data.copy()
data_copy.replace(clean_data, inplace=True)

# %% [markdown]
# we have to split data into x and y for training and testing phase

# %%
x=data_copy.iloc[:,0:-1]

# %%
x
# Out:
#       age     bmi  children  smoker  region
# 0      19  27.900         0       1       3
# 1      18  33.770         1       0       2
# 2      28  33.000         3       0       2
# 3      33  22.705         0       0       0
# 4      32  28.880         0       0       0
# ...   ...     ...       ...     ...     ...
# 1333   50  30.970         3       0       0
# 1334   18  31.920         0       0       1
# 1335   18  36.850         0       0       2
# 1336   21  25.800         0       0       3
# 1337   61  29.070         0       1       0
#
# [1338 rows x 5 columns]

# %%
y=data_copy.iloc[:,-1]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x.shape
# Out:
# (1338, 5)

# %%
y.shape
# Out:
# (1338,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train.shape
# Out:
# (936, 5)

# %%
x_test.shape
# Out:
# (402, 5)

# %%
x_train
# Out:
#       age     bmi  children  smoker  region
# 332    61  31.160         0       0       0
# 355    46  27.600         0       0       3
# 138    54  31.900         3       0       2
# 381    55  30.685         0       1       1
# 292    25  45.540         2       1       2
# ...   ...     ...       ...     ...     ...
# 1095   18  31.350         4       0       1
# 1130   39  23.870         5       0       2
# 1294   58  25.175         0       0       1
# 860    37  47.600         2       1       3
# 1126   55  29.900         0       0       3
#
# [936 rows x 5 columns]

# %%
x_test
# Out:
#       age     bmi  children  smoker  region
# 764    45  25.175         2       0       1
# 887    36  30.020         0       0       0
# 890    64  26.885         0       1       0
# 1293   46  25.745         3       0       0
# 259    19  31.920         0       1       0
# ...   ...     ...       ...     ...     ...
# 701    50  44.745         0       0       1
# 672    36  29.700         0       0       2
# 1163   18  28.215         0       0       1
# 1103   58  36.080         0       0       2
# 1295   20  22.000         1       0       3
#
# [402 rows x 5 columns]

# %%
y_train
# Out:
# 332     13429.03540
# 355     24603.04837
# 138     27322.73386
# 381     42303.69215
# 292     42112.23560
#            ...
# 1095     4561.18850
# 1130     8582.30230
# 1294    11931.12525
# 860     46113.51100
# 1126    10214.63600
# Name: charges, Length: 936, dtype: float64

# %%
y_test
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
#            ...
# 701      9541.69555
# 672      4399.73100
# 1163     2200.83085
# 1103    11363.28320
# 1295     1964.78000
# Name: charges, Length: 402, dtype: float64

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
y_test.shape
# Out:
# (402,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
clean_data = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
data_copy = data.copy()
data_copy.replace(clean_data, inplace=True)

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -12335.581540626896

# %%
lm.coef_
# Out:
# array([  261.53782368,   340.68179384,   426.57707914, 23637.82282961,
#         -227.80403479])

# %%
lm.score(x_train,y_train)
# Out:
# 0.7417727705035296

# %% [markdown]
# LM model is 74% accurate

# %% [markdown]
# now testing phase

# %%
pred=lm.predict(x_test)
print("predicted result", pred)
print("actual results",y_test)
# Out:
# predicted result [ 8635.63480851  7307.04756308 37199.89203203  9745.74236861
#  27146.02279843 10915.11839521   304.08769772 17316.3825706
#    650.0617032  11533.66372253 28057.33090224  9662.07946225
#   5300.75863552 38584.97831543 40479.60164434 37258.21414296
#  15417.61686969 36044.66212004  9222.25167556 31707.59773475
#   3794.63221558 10186.51341086  2306.9515378   6751.28534954
#  11601.01292372 12693.13792616 14631.20673976  6362.39746904
#   9644.1820121   2184.64048252  9130.80417841 13414.27249826
#   4580.67883844  3586.8861944   4428.02066516 12766.65529419
#   1893.87708892  8840.09548834 33549.43688496 32680.57109436
#   3826.60970458  4525.20189652 14250.10977987 11768.90852779
#   8872.08685947 12207.064362    5466.99564194  3077.75077485
#  35626.81499966  9248.41114786 16052.44239821  2348.89258039
#  12663.54838678  1044.60711502 13584.60267796 12305.95216723
#   3956.50760628 32405.69195081 13426.76750471 12625.78872497
# ...

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared eooer:', mean_squared_error(y_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 4154.810587717139
# Mean squared eooer: 33790162.273613125
# Root Mean Squared Error: 5812.930609736635

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.7695459725681215

# %% [markdown]
# now predict the insurance cost by providing the input values

# %%
t=np.array([45,25.175,2,0,1])

# %%
t.shape
# Out:
# (5,)

# %%
t=t.reshape(1,-1)

# %%
t
# Out:
# array([[45.   , 25.175,  2.   ,  0.   ,  1.   ]])

# %%
lm.predict(t)
# Out:
# C:\Users\AdmiN\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8635.63480851])

# %%
df=pd.DataFrame(pred)

# %%
df
# Out:
#                 0
# 0     8635.634809
# 1     7307.047563
# 2    37199.892032
# 3     9745.742369
# 4    27146.022798
# ..            ...
# 397  15757.312474
# 398   6742.421319
# 399   1756.632064
# 400  14669.803285
# 401    133.339372
#
# [402 rows x 1 columns]
