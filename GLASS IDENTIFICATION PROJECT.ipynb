# %%
import numpy as np
import pandas as pd 
import  matplotlib
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
ds=pd.read_csv("Glass Identification.csv")

# %%
ds
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
ds.head(20)
# Out:
#      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0    2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1    3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2    4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3    5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4    6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1
# 5    7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17   0.0    0.00    1
# 6    8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24   0.0    0.00    1
# 7    9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30   0.0    0.00    1
# 8   10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40   0.0    0.11    1
# 9   11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09   0.0    0.24    1
# 10  12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56   0.0    0.00    1
# 11  13  1.51589  12.88  3.43  1.40  73.28  0.69  8.05   0.0    0.24    1
# ...

# %%
ds.tail(20)
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 193  195  1.51683  14.56   0.0  1.98  73.29  0.00  8.52  1.57    0.07    7
# 194  196  1.51545  14.14   0.0  2.68  73.39  0.08  9.07  0.61    0.05    7
# 195  197  1.51556  13.87   0.0  2.54  73.23  0.14  9.41  0.81    0.01    7
# 196  198  1.51727  14.70   0.0  2.34  73.28  0.00  8.95  0.66    0.00    7
# 197  199  1.51531  14.38   0.0  2.66  73.10  0.04  9.08  0.64    0.00    7
# 198  200  1.51609  15.01   0.0  2.51  73.05  0.05  8.83  0.53    0.00    7
# 199  201  1.51508  15.15   0.0  2.25  73.50  0.00  8.34  0.63    0.00    7
# 200  202  1.51653  11.95   0.0  1.19  75.18  2.70  8.93  0.00    0.00    7
# 201  203  1.51514  14.85   0.0  2.42  73.72  0.00  8.39  0.56    0.00    7
# 202  204  1.51658  14.80   0.0  1.99  73.11  0.00  8.28  1.71    0.00    7
# 203  205  1.51617  14.95   0.0  2.27  73.30  0.00  8.71  0.67    0.00    7
# ...

# %%
ds.head(100)
# Out:
#       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0     2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1     3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2     4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3     5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4     6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..  ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 95   97  1.51841  13.02  3.62  1.06  72.34  0.64  9.13  0.00    0.15    2
# 96   98  1.51743  12.20  3.25  1.16  73.55  0.62  8.90  0.00    0.24    2
# 97   99  1.51689  12.67  2.88  1.71  73.21  0.73  8.54  0.00    0.00    2
# 98  100  1.51811  12.96  2.96  1.43  72.92  0.60  8.79  0.14    0.00    2
# 99  101  1.51655  12.75  2.85  1.44  73.27  0.57  8.79  0.11    0.22    2
#
# [100 rows x 11 columns]

# %%
ds.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        213 non-null    int64
#  1   1.52101  213 non-null    float64
#  2   13.64    213 non-null    float64
#  3   4.49     213 non-null    float64
#  4   1.10     213 non-null    float64
#  5   71.78    213 non-null    float64
#  6   0.06     213 non-null    float64
#  7   8.75     213 non-null    float64
#  8   0.00     213 non-null    float64
#  9   0.00.1   213 non-null    float64
#  10  1.1      213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
ds.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
ds.shape
# Out:
# (213, 11)

# %%
ds=ds[ds.columns[1:11]]

# %%
ds.columns=["RI","Na","Mg","Al","Si","K","Ca","Ba","Fe","Class"]

# %%
ds
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Class
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00      1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00      1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00      1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00      1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26      1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...    ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00      7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00      7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00      7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00      7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00      7
#
# [213 rows x 10 columns]

# %%
ds.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Class'], dtype='object')

# %%
ds.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe       Class
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# ...

# %% [markdown]
# # from above data it is observed that - median is greater that mean in mg,k that means data is not distributed in particular coloumns
# # Difference between 75% percentile and max is high in column ca,Na -outliers present in partiular coumn.

# %%
ds["RI"].plot.box()
# Out:
# <Axes: >

# %%
ds["Na"].plot.box()
# Out:
# <Axes: >

# %%
ds["Mg"].plot.box()
# Out:
# <Axes: >

# %%
ds.plot(kind="box",subplots=True,layout=(4,3))
# Out:
# RI          Axes(0.125,0.712609;0.227941x0.167391)
# Na       Axes(0.398529,0.712609;0.227941x0.167391)
# Mg       Axes(0.672059,0.712609;0.227941x0.167391)
# Al          Axes(0.125,0.511739;0.227941x0.167391)
# Si       Axes(0.398529,0.511739;0.227941x0.167391)
# K        Axes(0.672059,0.511739;0.227941x0.167391)
# Ca           Axes(0.125,0.31087;0.227941x0.167391)
# Ba        Axes(0.398529,0.31087;0.227941x0.167391)
# Fe        Axes(0.672059,0.31087;0.227941x0.167391)
# Class           Axes(0.125,0.11;0.227941x0.167391)
# dtype: object

# %%
sns.countplot(ds)
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(ds)

# %%
from scipy.stats import zscore

# %%
np.abs(zscore(ds))
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.245101  0.591880  0.642937  0.173500  0.097091  0.029329  0.792599
# 1    0.716826  0.150946  0.608144  0.187433  0.433777  0.167472  0.827734
# 2    0.228607  0.240996  0.705564  0.313863  0.058303  0.108813  0.518546
# 3    0.307777  0.167507  0.656854  0.414122  0.550322  0.078115  0.623951
# 4    0.789399  0.755419  0.649895  0.347848  0.407878  0.216258  0.623951
# ..        ...       ...       ...       ...       ...       ...       ...
# 208  0.700332  0.898085  1.862164  2.874379  0.058303  0.643296  0.156046
# 209  0.495808  1.853443  1.862164  1.089766  0.524423  0.766090  0.392060
# 210  0.757727  1.167545  1.862164  1.149921  0.990604  0.766090  0.363952
# 211  0.607966  1.192041  1.862164  0.989506  1.236644  0.766090  0.335844
# 212  0.410039  1.008318  1.862164  1.270232  0.912907  0.766090  0.237466
#
#            Ba        Fe     Class
# 0    0.353808  0.588301  0.851703
# ...

# %%
ds.skew()
# Out:
# RI       1.639658
# Na       0.457318
# Mg      -1.154323
# Al       0.900017
# Si      -0.744546
# K        6.549276
# Ca       2.040591
# Ba       3.406749
# Fe       1.747173
# Class    1.108861
# dtype: float64

# %% [markdown]
# k has max skew data remove skewness

# %%
from scipy.stats import boxcox

# %%
ds["K"]=boxcox(ds["K"],0)

# %%
ds["K"].plot.hist,0
# Out:
# (<bound method PlotAccessor.hist of <pandas.plotting._core.PlotAccessor object at 0x000002650CBDEA70>>,
#  0)

# %%
ds["K"]=boxcox(ds["K"],0)

# %%
ds["K"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ds["Ba"]=boxcox(ds["Ba"],0)

# %%
ds["Ba"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ds.hist(figsize=(10,10),bins=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 ds.hist(figsize=(10,10),bins=50)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:231, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     140 """
#     141 Make a histogram of the DataFrame's columns.
#     142
#    (...)
#     228     >>> hist = df.hist(bins=3)
#     229 """
#     230 plot_backend = _get_plot_backend(backend)
# --> 231 return plot_backend.hist_frame(
#     232     data,
#     233     column=column,
#     234     by=by,
#     235     grid=grid,
#     236     xlabelsize=xlabelsize,
#     237     xrot=xrot,
#     238     ylabelsize=ylabelsize,
#     239     yrot=yrot,
#     240     ax=ax,
#     241     sharex=sharex,
#     242     sharey=sharey,
# ...

# %%
corr_hmap=ds.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# Negative coreelation between AL and mg

# %%
from scipy import stats 
from scipy.stats import zscore

# %%
z=np.abs(zscore(ds))
z
# Out:
# C:\Users\AdmiN\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#            RI        Na        Mg        Al        Si   K        Ca  Ba  \
# 0    0.245101  0.591880  0.642937  0.173500  0.097091 NaN  0.792599 NaN
# 1    0.716826  0.150946  0.608144  0.187433  0.433777 NaN  0.827734 NaN
# 2    0.228607  0.240996  0.705564  0.313863  0.058303 NaN  0.518546 NaN
# 3    0.307777  0.167507  0.656854  0.414122  0.550322 NaN  0.623951 NaN
# 4    0.789399  0.755419  0.649895  0.347848  0.407878 NaN  0.623951 NaN
# ..        ...       ...       ...       ...       ...  ..       ...  ..
# 208  0.700332  0.898085  1.862164  2.874379  0.058303 NaN  0.156046 NaN
# 209  0.495808  1.853443  1.862164  1.089766  0.524423 NaN  0.392060 NaN
# 210  0.757727  1.167545  1.862164  1.149921  0.990604 NaN  0.363952 NaN
# 211  0.607966  1.192041  1.862164  0.989506  1.236644 NaN  0.335844 NaN
# ...

# %%
print(np.where(z>3))
# Out:
# (array([104, 105, 105, 105, 105, 106, 106, 106, 109, 110, 111, 111, 130,
#        144, 161, 162, 162, 170, 171, 173, 183, 183, 187, 200], dtype=int64), array([6, 0, 1, 4, 6, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 3, 3, 8, 1, 4,
#        4, 4], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]

# %%
ds_new
# Out:
# Empty DataFrame
# Columns: [RI, Na, Mg, Al, Si, K, Ca, Ba, Fe, Class, k]
# Index: []

# %%
ds_new.shape
# Out:
# (0, 11)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x=ds_new.iloc[:,0:-1]

# %%
x
# Out:
# Empty DataFrame
# Columns: [RI, Na, Mg, Al, Si, K, Ca, Ba, Fe, Class]
# Index: []

# %%
y=ds_new.iloc[:,-1]

# %%
y
# Out:
# Series([], Name: k, dtype: float64)

# %%
x_train
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 12   1.51748  12.86  3.56  1.27  73.21  0.54   8.38  0.00  0.17
# 41   1.51779  13.21  3.39  1.33  72.76  0.59   8.59  0.00  0.00
# 181  1.51916  14.15  0.00  2.09  72.74  0.00  10.88  0.00  0.00
# 209  1.51685  14.92  0.00  1.99  73.06  0.00   8.40  1.59  0.00
# 203  1.51617  14.95  0.00  2.27  73.30  0.00   8.71  0.67  0.00
# ..       ...    ...   ...   ...    ...   ...    ...   ...   ...
# 112  1.51892  13.46  3.83  1.26  72.55  0.57   8.21  0.00  0.14
# 14   1.51761  12.81  3.54  1.23  73.24  0.58   8.39  0.00  0.00
# 92   1.51590  13.24  3.34  1.47  73.10  0.39   8.22  0.00  0.00
# 195  1.51556  13.87  0.00  2.54  73.23  0.14   9.41  0.81  0.01
# 102  1.52725  13.80  3.15  0.66  70.57  0.08  11.64  0.00  0.00
#
# [135 rows x 9 columns]

# %%
x_train.shape
# Out:
# (135, 9)

# %%
x_test.shape
# Out:
# (58, 9)

# %%
x_test
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 45   1.51869  13.19  3.37  1.18  72.72  0.57   8.83  0.00  0.16
# 145  1.51769  13.65  3.66  1.11  72.77  0.11   8.60  0.00  0.00
# 76   1.51627  13.00  3.58  1.54  72.83  0.61   8.04  0.00  0.00
# 152  1.51610  13.42  3.40  1.22  72.69  0.59   8.32  0.00  0.00
# 119  1.51844  13.25  3.76  1.32  72.40  0.58   8.42  0.00  0.00
# 160  1.51934  13.64  3.54  0.75  72.65  0.16   8.89  0.15  0.24
# 15   1.51784  12.68  3.67  1.16  73.11  0.61   8.70  0.00  0.00
# 18   1.51735  13.02  3.54  1.69  72.73  0.54   8.44  0.00  0.07
# 16   1.52196  14.36  3.85  0.89  71.36  0.15   9.15  0.00  0.00
# 9    1.51571  12.72  3.46  1.56  73.20  0.67   8.09  0.00  0.24
# 78   1.51590  12.82  3.52  1.90  72.86  0.69   7.97  0.00  0.00
# 118  1.51652  13.56  3.57  1.47  72.45  0.64   7.96  0.00  0.00
# 66   1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.00  0.17
# 65   1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.00  0.17
# ...

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predlm=lm.predict(x_test)

# %%
predlm
# Out:
# array([1.47049281, 1.80540626, 1.96475022, 2.0629438 , 1.52203926,
#        1.40381206, 1.20268231, 2.0529459 , 1.39512382, 1.84140571,
#        2.30341676, 2.10187939, 0.99194689, 1.03129183, 2.40596152,
#        1.32229735, 1.90870367, 3.05451937, 1.86136314, 1.03575754,
#        4.40805509, 2.1349706 , 1.60162128, 2.20663614, 1.09981237,
#        1.89196611, 1.4176502 , 4.09605194, 3.1845582 , 1.58493782,
#        1.80025648, 4.66933554, 1.73568711, 2.04963304, 4.842836  ,
#        1.33875218, 2.18996309, 1.38669483, 3.61207036, 2.01969357,
#        1.52580202, 2.65168528, 2.22881959, 1.909422  , 1.057821  ,
#        6.66171692, 1.29327359, 2.47180893, 2.16558478, 1.29079771,
#        1.3733562 , 0.76018985, 1.37435163, 2.05806751, 3.56966388,
#        0.92471981, 1.50530055, 4.02478652])

# %%
lm.intercept_
# Out:
# 375.1349301193407

# %%
lm.coef_
# Out:
# array([-230.51068792,    0.26034068,   -0.56078096,    0.94628629,
#          -0.39344938,   -0.5087278 ,    0.30813301,    1.65764229,
#          -0.43775525])

# %%
lm.score(x_train,y_train)
# Out:
# 0.8420941311088799

# %%
pred=lm.predict(x_test)
print("predicted result", pred)
print("actual results",y_test)
# Out:
# predicted result [1.47049281 1.80540626 1.96475022 2.0629438  1.52203926 1.40381206
#  1.20268231 2.0529459  1.39512382 1.84140571 2.30341676 2.10187939
#  0.99194689 1.03129183 2.40596152 1.32229735 1.90870367 3.05451937
#  1.86136314 1.03575754 4.40805509 2.1349706  1.60162128 2.20663614
#  1.09981237 1.89196611 1.4176502  4.09605194 3.1845582  1.58493782
#  1.80025648 4.66933554 1.73568711 2.04963304 4.842836   1.33875218
#  2.18996309 1.38669483 3.61207036 2.01969357 1.52580202 2.65168528
#  2.22881959 1.909422   1.057821   6.66171692 1.29327359 2.47180893
#  2.16558478 1.29079771 1.3733562  0.76018985 1.37435163 2.05806751
#  3.56966388 0.92471981 1.50530055 4.02478652]
# actual results 45     1
# 145    3
# 76     2
# 152    3
# 119    2
# 160    3
# 15     1
# 18     1
# 16     1
# 9      1
# 78     2
# 118    2
# 66     1
# 65     1
# 164    5
# 30     1
# 154    3
# 69     2
# 117    2
# 68     1
# 168    5
# 142    2
# 124    2
# 98     2
# 67     1
# 121    2
# 24     1
# ...

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:', mean_squared_error(y_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 0.8898541973120826
# Mean squared error: 1.9306999045883855
# Root Mean Squared Error: 1.3894962772848243

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.43007419453884443
